# %% [markdown]
# Create a new Python application

# %%
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient
from msrest.authentication import ApiKeyCredentials
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont
import numpy as np
import os

# %% [markdown]
# Create variables for your resource's Azure endpoint and keys.

# %%
prediction_endpoint = "https://smu2110861findbungee-prediction.cognitiveservices.azure.com"
prediction_key = "12ndCviZ6IX6geYBi9tgODPzeSZC3NRlKeJkxx50aLusUETMAX5KJQQJ99BDACi0881XJ3w3AAAIACOG3ZBA"
project_id = "5d60753d-6cc7-47f9-8877-ff0587bdcc9c"
model_name = "Iteration1"

# %% [markdown]
# Authenticate the client

# %%
credentials = ApiKeyCredentials(in_headers={"Prediction-key": prediction_key})
predictor = CustomVisionPredictionClient(endpoint=prediction_endpoint, credentials=credentials)
# Test

# %% [markdown]
# Load image and get height, width and channels

# %%
image_file = "./data/test-1.png"
print('Detecting objects in ', image_file)
image=Image.open(image_file)
h, w, ch = np.array(image).shape
print(h)
print(w)
print(ch)
# Out:
# Detecting objects in  ./data/test-1.png
# 791
# 1410
# 3

# %% [markdown]
# Detect objects in the test image

# %%
with open(image_file, mode="rb") as image_data:
    results = predictor.detect_image(project_id, model_name, image_data)

# Display the results.    
for prediction in results. predictions:
    print("\t" + prediction.tag_name + ": {0:.2f}% bbox.left = {1:.2f}, bbox.top = {2:.2f}, bbox.width = {3:.2f}, bbox.height = {4:.2f}".format(prediction.probability * 100, prediction.bounding_box.left, prediction.bounding_box.top, prediction.bounding_box.width, prediction.bounding_box.height))
# Out:
# 	Bungee: 99.78% bbox.left = 0.08, bbox.top = 0.38, bbox.width = 0.60, bbox.height = 0.48
# 	Bungee: 78.95% bbox.left = 0.60, bbox.top = 0.50, bbox.width = 0.40, bbox.height = 0.50
# 	Bungee: 52.47% bbox.left = 0.01, bbox.top = 0.02, bbox.width = 0.12, bbox.height = 0.72
# 	Bungee: 36.44% bbox.left = 0.22, bbox.top = 0.18, bbox.width = 0.42, bbox.height = 0.82
# 	Bungee: 18.74% bbox.left = 0.63, bbox.top = 0.34, bbox.width = 0.35, bbox.height = 0.66
# 	Bungee: 6.27% bbox.left = 0.08, bbox.top = 0.41, bbox.width = 0.92, bbox.height = 0.59
# 	Bungee: 5.83% bbox.left = 0.72, bbox.top = 0.92, bbox.width = 0.28, bbox.height = 0.08
# 	Bungee: 5.72% bbox.left = 0.00, bbox.top = 0.51, bbox.width = 0.02, bbox.height = 0.26
# 	Bungee: 3.14% bbox.left = 0.91, bbox.top = 0.27, bbox.width = 0.09, bbox.height = 0.19
# 	Bungee: 2.51% bbox.left = 0.74, bbox.top = 0.57, bbox.width = 0.26, bbox.height = 0.41
# 	Bungee: 1.88% bbox.left = 0.01, bbox.top = 0.00, bbox.width = 0.18, bbox.height = 1.00

# %% [markdown]
# Create a figure for the results
# Display the image with boxes around each detected object

# %%
fig = plt.figure(figsize=(8,8))
plt.axis('off')

draw = ImageDraw.Draw(image)
lineWidth = int(w/100)
color = 'magenta'

for prediction in results. predictions:

    if (prediction.probability*100) > 50:
        left = prediction.bounding_box.left * w
        top = prediction.bounding_box.top * h
        width = prediction.bounding_box.width * w
        height = prediction.bounding_box.height * h

        points = ((left,top), (left+width,top), (left+width,top+height), (left,top+height),(left,top))
        draw.line(points, fill=color, width=lineWidth)
        plt.annotate(prediction.tag_name + ' {0:.2f}%'.format(prediction.probability * 100), (left, top), color=color)
        
plt.imshow(image)
outputfile = 'output.jpg'
fig. savefig(outputfile)
print('Results saved in', outputfile)
# Out:
# Results saved in output.jpg
